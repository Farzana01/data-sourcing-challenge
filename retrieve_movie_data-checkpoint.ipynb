# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import numpy as np
import urllib.parse
import re

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
##Load environment variables and New York Times Api key
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
url = f"{url}api-key={nyt_api_key}"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
#filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'
headline = 'love'
section_name = 'Movies'
type_of_material = 'Review'

filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "web_url,snippet,source,headline,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
#query_url = f"{url}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"
query_url = f"{url}&api-key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=5SFLb5KyrkJ92GExnr3G9v02UJDpfKCl&api-key=5SFLb5KyrkJ92GExnr3G9v02UJDpfKCl&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=web_url,snippet,source,headline,keywords,pub_date,byline,word_count&begin_date=20130101&end_date=20230531

# %%
# Create an empty list to store the reviews
reviews_list=[]

# loop through pages 0-19
for page in range(0, 20):
        
        # create query with a page number
        # API results show 10 articles at a time
        query_url = f"{query_url}&page={str(page)}"
        
        # Make a "GET" request and retrieve the JSON
        response = requests.get(query_url)
        reviews = response.json()
        print("Checked page", page) 
       
       
        # Add a twelve second interval between queries to stay within API query limits
        time.sleep(12)
    
        # Try and save the reviews to the reviews_list
        try:
            reviews_list.extend(reviews["response"]["docs"])
    
        except:
            # Handle exceptions for a review that is missing a data point
            print("Missing page.")
        
            # loop through the reviews["response"]["docs"] and append each review to the list
            if reviews ["response"]["docs"]:
                reviews_list.extend(reviews["response"]["docs"])
                page += 1
        
            #Print the page that was just retrieved
                print(f"Retrieving page {page}")
        
            # Print the page number that had no results then break from the loop
            else:
                print(f"Page {page} has no results.")
                break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

reviews_df['title'] = reviews_df['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;persons: Bracey, Luke (1989- )...
# 196  subject: Documentary Films and Programs;creati...
# 197  subject: Movies;creative_works: A Thousand and...
# 198  subject: Movies;creative_works: Your Place or ...
# 199  subject: Documentary Films and Programs;subjec...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 One True Loves
# 196                 The Lost Weekend: A Love Story
# 197                             A Thousand and One
# 198                             Your Place or Mine
# 199                   Love in the Time of Fentanyl
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database

titles = reviews_df["title"].to_list()
# remove duplicate titles
titles = list(dict.fromkeys(titles))
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []


# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 0


# Loop through the titles
for title in titles:
    
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        print("Sleeping for 5 seconds to comply with TMDb rate limits...")
        time.sleep(5)
        
    # Add 1 to the request counter
    request_counter +=1

    
    # Perform a "GET" request for The Movie Database
    tmdb_query_url = f'https://api.themoviedb.org/3/search/movie?api_key={tmdb_api_key}&query={title}'
   
      
    # Include a try clause to search for the full movie details.
    try:
        # Execute "GET" request with url
        response = requests.get(tmdb_query_url)
        data = response.json()
        # Get movie id
        # Check if any movies were found
        if data['total_results'] > 0:
            # Get movie id
            movie_id = data['results'][0]['id']
       
        # Make a request for a the full movie details
            details_url = f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}'
              
          
        # Execute "GET" request with url
            details_response = requests.get(details_url)
            details_data = details_response.json()
       
        # Extract the genre names into a list
            genres = [genre['name'] for genre in details_data['genres']]
        
        # Extract the spoken_languages' English name into a list
            spoken_languages = [language['english_name'] for language in details_data['spoken_languages']]

        # Extract the production_countries' name into a list
            production_countries = [country['name'] for country in details_data['production_countries']]


            movie_info = {
                 
                'title': details_data['title'],
                'original_title': details_data['original_title'],
                'budget': details_data['budget'],
                'genres': genres,
                'language': details_data['original_language'],
                'spoken_languages': spoken_languages,
                'homepage': details_data['homepage'],
                'overview': details_data['overview'],
                'popularity': details_data['popularity'],
                'runtime': details_data['runtime'],
                'revenue': details_data['revenue'],
                'release_date': details_data['release_date'],
                'vote_average': movie_data.get("vote_average"),
                'vote_count': movie_data.get("vote_count"),
                'production_countries': production_countries              
            }
            tmdb_movies_list.append(movie_info)
            print(f"Found {details_data['title']}")
        else:
            print(f"{title}","not found.")
        
    
    # Use the except clause to print out a statement if a movie
    # is not found.
    except Exception as e:
        print(f"Error processing {title}: {e}")

# Print the final list of movie information
print("\nFinal List of Movie Information:")
for movie in tmdb_movies_list:
    print(movie)
    print("\n")
# Out:
# Found The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever
# Found A Tourist's Guide to Love
# Found Other People's Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
#
# Final List of Movie Information:
# {'title': 'The Attachment Diaries', 'original_title': 'El apego', 'budget': 0, 'genres': ['Drama', 'Mystery', 'Thriller', 'Horror'], 'language': 'es', 'spoken_languages': ['Spanish'], 'homepage': '', 'overview': 'Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.', 'popularity': 1.96, 'runtime': 102, 'revenue': 0, 'release_date': '2021-10-07', 'vote_average': None, 'vote_count': None, 'production_countries': ['Argentina']}
#
#
# {'title': 'You Can Live Forever', 'original_title': 'You Can Live Forever', 'budget': 0, 'genres': ['Drama', 'Romance'], 'language': 'en', 'spoken_languages': ['French', 'English'], 'homepage': 'https://gooddeedentertainment.com/you-can-live-forever/', 'overview': "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.", 'popularity': 11.531, 'runtime': 96, 'revenue': 0, 'release_date': '2022-06-11', 'vote_average': None, 'vote_count': None, 'production_countries': ['Canada']}
#
#
# {'title': "A Tourist's Guide to Love", 'original_title': "A Tourist's Guide to Love", 'budget': 0, 'genres': ['Romance', 'Comedy', 'Adventure'], 'language': 'en', 'spoken_languages': ['English'], 'homepage': 'https://www.netflix.com/title/81424906', 'overview': 'After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.', 'popularity': 24.838, 'runtime': 96, 'revenue': 0, 'release_date': '2023-04-21', 'vote_average': None, 'vote_count': None, 'production_countries': ['United States of America']}
#
#
# {'title': "Other People's Children", 'original_title': 'Les Enfants des autres', 'budget': 0, 'genres': ['Drama', 'Comedy'], 'language': 'fr', 'spoken_languages': ['English', 'French'], 'homepage': 'https://www.wildbunch.biz/movie/other-peoples-children/', 'overview': 'Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn’t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?', 'popularity': 12.254, 'runtime': 104, 'revenue': 84178, 'release_date': '2022-09-21', 'vote_average': None, 'vote_count': None, 'production_countries': ['France']}
#
#
# {'title': 'One True Loves', 'original_title': 'One True Loves', 'budget': 0, 'genres': ['Romance', 'Drama', 'Comedy'], 'language': 'en', 'spoken_languages': ['English'], 'homepage': '', 'overview': 'Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.', 'popularity': 19.222, 'runtime': 100, 'revenue': 37820, 'release_date': '2023-04-07', 'vote_average': None, 'vote_count': None, 'production_countries': ['Germany', 'United States of America']}
#
#
# {'title': 'The Lost Weekend: A Love Story', 'original_title': 'The Lost Weekend: A Love Story', 'budget': 0, 'genres': ['Documentary'], 'language': 'en', 'spoken_languages': ['English'], 'homepage': 'https://thelostweekendmovie.com/', 'overview': 'May Pang lovingly recounts her life in rock & roll and the whirlwind 18 months spent as friend, lover, and confidante to one of the towering figures of popular culture, John Lennon, in this funny, touching, and vibrant portrait of first love.', 'popularity': 14.126, 'runtime': 95, 'revenue': 0, 'release_date': '2023-04-13', 'vote_average': None, 'vote_count': None, 'production_countries': ['United States of America']}
#
#
# {'title': 'A Thousand and One', 'original_title': 'A Thousand and One', 'budget': 0, 'genres': ['Drama'], 'language': 'en', 'spoken_languages': ['English'], 'homepage': 'https://www.focusfeatures.com/a-thousand-and-one/', 'overview': 'Struggling but unapologetically living on her own terms, Inez is moving from shelter to shelter in mid-1990s New York City. With her 6-year-old son Terry in foster care and unable to leave him again, she kidnaps him so they can build their life together. As the years go by, their family grows and Terry becomes a smart yet quiet teenager, but the secret that has defined their lives threatens to destroy the home they have so improbably built.', 'popularity': 25.388, 'runtime': 116, 'revenue': 0, 'release_date': '2023-03-31', 'vote_average': None, 'vote_count': None, 'production_countries': ['United States of America']}
#
#
# {'title': 'Your Place or Mine', 'original_title': 'Your Place or Mine', 'budget': 0, 'genres': ['Romance', 'Comedy'], 'language': 'en', 'spoken_languages': ['English'], 'homepage': 'https://www.netflix.com/title/81045831', 'overview': "When best friends and total opposites Debbie and Peter swap homes for a week, they get a peek into each other's lives that could open the door to love.", 'popularity': 22.78, 'runtime': 109, 'revenue': 0, 'release_date': '2023-02-10', 'vote_average': None, 'vote_count': None, 'production_countries': ['United States of America']}
#
#
# {'title': 'Love in the Time of Fentanyl', 'original_title': 'Love in the Time of Fentanyl', 'budget': 0, 'genres': ['Documentary'], 'language': 'en', 'spoken_languages': ['English'], 'homepage': '', 'overview': 'An intimate portrait of a community fighting to save lives and keep hope alive in a neighborhood ravaged by the overdose crisis.', 'popularity': 4.863, 'runtime': 85, 'revenue': 0, 'release_date': '2023-02-03', 'vote_average': None, 'vote_count': None, 'production_countries': ['Canada', 'United States of America']}

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 1.96,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": null,
#         "vote_count": null,
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 11.531,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2022-06-11",
#         "vote_average": null,
#         "vote_count": null,
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "genres": [
#             "Romance",
#             "Comedy",
#             "Adventure"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 24.838,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": null,
#         "vote_count": null,
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "language": "fr",
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 12.254,
#         "runtime": 104,
#         "revenue": 84178,
#         "release_date": "2022-09-21",
#         "vote_average": null,
#         "vote_count": null,
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "genres": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 19.222,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": null,
#         "vote_count": null,
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_movies_df = pd.DataFrame(tmdb_movies_list)
tmdb_movies_df
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2       A Tourist's Guide to Love       A Tourist's Guide to Love       0
# 3         Other People's Children          Les Enfants des autres       0
# 4                  One True Loves                  One True Loves       0
# 5  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 6              A Thousand and One              A Thousand and One       0
# 7              Your Place or Mine              Your Place or Mine       0
# 8    Love in the Time of Fentanyl    Love in the Time of Fentanyl       0
#
#                                genres language   spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]       es          [Spanish]
# 1                    [Drama, Romance]       en  [French, English]
# 2        [Romance, Comedy, Adventure]       en          [English]
# 3                     [Drama, Comedy]       fr  [English, French]
# 4            [Romance, Drama, Comedy]       en          [English]
# 5                       [Documentary]       en          [English]
# 6                             [Drama]       en          [English]
# 7                   [Romance, Comedy]       en          [English]
# 8                       [Documentary]       en          [English]
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
# 5                   https://thelostweekendmovie.com/
# 6  https://www.focusfeatures.com/a-thousand-and-one/
# 7             https://www.netflix.com/title/81045831
# 8
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       1.960      102
# 1  When Jaime, a gay teenager, is sent to live in...      11.531       96
# 2  After an unexpected break up, a travel executi...      24.838       96
# 3  Rachel loves her life, her students, her frien...      12.254      104
# 4  Emma and Jesse are living the perfect life tog...      19.222      100
# 5  May Pang lovingly recounts her life in rock & ...      14.126       95
# 6  Struggling but unapologetically living on her ...      25.388      116
# 7  When best friends and total opposites Debbie a...      22.780      109
# 8  An intimate portrait of a community fighting t...       4.863       85
#
#    revenue release_date vote_average vote_count  \
# 0        0   2021-10-07         None       None
# 1        0   2022-06-11         None       None
# 2        0   2023-04-21         None       None
# 3    84178   2022-09-21         None       None
# 4    37820   2023-04-07         None       None
# 5        0   2023-04-13         None       None
# 6        0   2023-03-31         None       None
# 7        0   2023-02-10         None       None
# 8        0   2023-02-03         None       None
#
#                   production_countries
# 0                          [Argentina]
# 1                             [Canada]
# 2           [United States of America]
# 3                             [France]
# 4  [Germany, United States of America]
# 5           [United States of America]
# 6           [United States of America]
# 7           [United States of America]
# 8   [Canada, United States of America]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Use an inner join to keep only the movies that are in both DataFrames
merged_df = pd.merge(tmdb_movies_df, reviews_df, on="title", how="inner")
merged_df
# Out:
#                             title                original_title  budget  \
# 0          The Attachment Diaries                      El apego       0
# 1          The Attachment Diaries                      El apego       0
# 2          The Attachment Diaries                      El apego       0
# 3          The Attachment Diaries                      El apego       0
# 4          The Attachment Diaries                      El apego       0
# ..                            ...                           ...     ...
# 135  Love in the Time of Fentanyl  Love in the Time of Fentanyl       0
# 136  Love in the Time of Fentanyl  Love in the Time of Fentanyl       0
# 137  Love in the Time of Fentanyl  Love in the Time of Fentanyl       0
# 138  Love in the Time of Fentanyl  Love in the Time of Fentanyl       0
# 139  Love in the Time of Fentanyl  Love in the Time of Fentanyl       0
#
#                                  genres language spoken_languages homepage  \
# 0    [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 1    [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 2    [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 3    [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 4    [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# ..                                  ...      ...              ...      ...
# 135                       [Documentary]       en        [English]
# 136                       [Documentary]       en        [English]
# 137                       [Documentary]       en        [English]
# 138                       [Documentary]       en        [English]
# 139                       [Documentary]       en        [English]
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       1.960      102
# 1    Argentina, 1970s. A desperate young woman goes...       1.960      102
# 2    Argentina, 1970s. A desperate young woman goes...       1.960      102
# 3    Argentina, 1970s. A desperate young woman goes...       1.960      102
# 4    Argentina, 1970s. A desperate young woman goes...       1.960      102
# ..                                                 ...         ...      ...
# 135  An intimate portrait of a community fighting t...       4.863       85
# 136  An intimate portrait of a community fighting t...       4.863       85
# 137  An intimate portrait of a community fighting t...       4.863       85
# 138  An intimate portrait of a community fighting t...       4.863       85
# 139  An intimate portrait of a community fighting t...       4.863       85
#
#      ...                                      headline.main headline.kicker  \
# 0    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 2    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 3    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 4    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# ..   ...                                                ...             ...
# 135  ...  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 136  ...  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 137  ...  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 138  ...  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 139  ...  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker       headline.print_headline headline.name  \
# 0                      None        The Attachment Diaries          None
# 1                      None        The Attachment Diaries          None
# 2                      None        The Attachment Diaries          None
# 3                      None        The Attachment Diaries          None
# 4                      None        The Attachment Diaries          None
# ..                      ...                           ...           ...
# 135                    None  Love in the Time Of Fentanyl          None
# 136                    None  Love in the Time Of Fentanyl          None
# 137                    None  Love in the Time Of Fentanyl          None
# 138                    None  Love in the Time Of Fentanyl          None
# 139                    None  Love in the Time Of Fentanyl          None
#
#     headline.seo headline.sub         byline.original  \
# 0           None         None  By Jeannette Catsoulis
# 1           None         None  By Jeannette Catsoulis
# 2           None         None  By Jeannette Catsoulis
# 3           None         None  By Jeannette Catsoulis
# 4           None         None  By Jeannette Catsoulis
# ..           ...          ...                     ...
# 135         None         None   By Concepción de León
# 136         None         None   By Concepción de León
# 137         None         None   By Concepción de León
# 138         None         None   By Concepción de León
# 139         None         None   By Concepción de León
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Jeannette', 'middlename': None...                None
# 3    [{'firstname': 'Jeannette', 'middlename': None...                None
# 4    [{'firstname': 'Jeannette', 'middlename': None...                None
# ..                                                 ...                 ...
# 135  [{'firstname': 'Concepción', 'middlename': Non...                None
# 136  [{'firstname': 'Concepción', 'middlename': Non...                None
# 137  [{'firstname': 'Concepción', 'middlename': Non...                None
# 138  [{'firstname': 'Concepción', 'middlename': Non...                None
# 139  [{'firstname': 'Concepción', 'middlename': Non...                None
#
# [140 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries"]




# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]


# Loop through the list of columns to fix
for column in columns_to_fix:

    # Convert the column to type 'str'
    tmdb_movies_df[column] = tmdb_movies_df[column].astype(str)


    # Loop through characters to remove
    for character in characters_to_remove:
        # Remove the character
        tmdb_movies_df[column] = tmdb_movies_df[column].str.replace(character, "")

# Display the fixed DataFrame
tmdb_movies_df.head()
# Out:
#                        title             original_title  budget  \
# 0     The Attachment Diaries                   El apego       0
# 1       You Can Live Forever       You Can Live Forever       0
# 2  A Tourist's Guide to Love  A Tourist's Guide to Love       0
# 3    Other People's Children     Les Enfants des autres       0
# 4             One True Loves             One True Loves       0
#
#                              genres language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2        Romance, Comedy, Adventure       en          English
# 3                     Drama, Comedy       fr  English, French
# 4            Romance, Drama, Comedy       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       1.960      102
# 1  When Jaime, a gay teenager, is sent to live in...      11.531       96
# 2  After an unexpected break up, a travel executi...      24.838       96
# 3  Rachel loves her life, her students, her frien...      12.254      104
# 4  Emma and Jesse are living the perfect life tog...      19.222      100
#
#    revenue release_date vote_average vote_count  \
# 0        0   2021-10-07         None       None
# 1        0   2022-06-11         None       None
# 2        0   2023-04-21         None       None
# 3    84178   2022-09-21         None       None
# 4    37820   2023-04-07         None       None
#
#                 production_countries
# 0                          Argentina
# 1                             Canada
# 2           United States of America
# 3                             France
# 4  Germany, United States of America

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=["byline.person"])
merged_df.head()
# Out:
#                     title original_title  budget  \
# 0  The Attachment Diaries       El apego       0
# 1  The Attachment Diaries       El apego       0
# 2  The Attachment Diaries       El apego       0
# 3  The Attachment Diaries       El apego       0
# 4  The Attachment Diaries       El apego       0
#
#                                genres language spoken_languages homepage  \
# 0  [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 1  [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 2  [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 3  [Drama, Mystery, Thriller, Horror]       es        [Spanish]
# 4  [Drama, Mystery, Thriller, Horror]       es        [Spanish]
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...        1.96      102
# 1  Argentina, 1970s. A desperate young woman goes...        1.96      102
# 2  Argentina, 1970s. A desperate young woman goes...        1.96      102
# 3  Argentina, 1970s. A desperate young woman goes...        1.96      102
# 4  Argentina, 1970s. A desperate young woman goes...        1.96      102
#
#    ...  word_count                                headline.main  \
# 0  ...         295  ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         295  ‘The Attachment Diaries’ Review: Love, Sick
# 2  ...         295  ‘The Attachment Diaries’ Review: Love, Sick
# 3  ...         295  ‘The Attachment Diaries’ Review: Love, Sick
# 4  ...         295  ‘The Attachment Diaries’ Review: Love, Sick
#
#   headline.kicker headline.content_kicker headline.print_headline  \
# 0            None                    None  The Attachment Diaries
# 1            None                    None  The Attachment Diaries
# 2            None                    None  The Attachment Diaries
# 3            None                    None  The Attachment Diaries
# 4            None                    None  The Attachment Diaries
#
#   headline.name headline.seo headline.sub         byline.original  \
# 0          None         None         None  By Jeannette Catsoulis
# 1          None         None         None  By Jeannette Catsoulis
# 2          None         None         None  By Jeannette Catsoulis
# 3          None         None         None  By Jeannette Catsoulis
# 4          None         None         None  By Jeannette Catsoulis
#
#   byline.organization
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 30 columns]

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates(subset=["title"])
merged_df = merged_df.reset_index(drop=True)
merged_df.head()
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                                genres language   spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]       es          [Spanish]
# 1                    [Drama, Romance]       en  [French, English]
# 2            [Romance, Drama, Comedy]       en          [English]
# 3                       [Documentary]       en          [English]
# 4                             [Drama]       en          [English]
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3                   https://thelostweekendmovie.com/
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       1.960      102
# 1  When Jaime, a gay teenager, is sent to live in...      11.531       96
# 2  Emma and Jesse are living the perfect life tog...      19.222      100
# 3  May Pang lovingly recounts her life in rock & ...      14.126       95
# 4  Struggling but unapologetically living on her ...      25.388      116
#
#    ...  word_count                                      headline.main  \
# 0  ...         295        ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         294  ‘You Can Live Forever’ Review: Do You Love Me ...
# 2  ...         320     ‘One True Loves’ Review: A Romance Lost at Sea
# 3  ...         327  ‘The Lost Weekend: A Love Story’ Review: When ...
# 4  ...         971  ‘A Thousand and One’ Review: A New York Love S...
#
#   headline.kicker headline.content_kicker  \
# 0            None                    None
# 1            None                    None
# 2            None                    None
# 3            None                    None
# 4   Critic’s Pick                    None
#
#                    headline.print_headline headline.name headline.seo  \
# 0                   The Attachment Diaries          None         None
# 1                     You Can Live Forever          None         None
# 2                           One True Loves          None         None
# 3          The Lost Weekend:  A Love Story          None         None
# 4  An Unbending Will Meets a Shifting City          None         None
#
#   headline.sub           byline.original byline.organization
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
# [5 rows x 30 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv("Resources/merged_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\farza\AI_BOOTCAMP\Module_6_challenge\data-sourcing-challenge\retrieve_movie_data-checkpoint.ipynb Cell 22 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/farza/AI_BOOTCAMP/Module_6_challenge/data-sourcing-challenge/retrieve_movie_data-checkpoint.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Export data to CSV without the index
# ----> <a href='vscode-notebook-cell:/c%3A/Users/farza/AI_BOOTCAMP/Module_6_challenge/data-sourcing-challenge/retrieve_movie_data-checkpoint.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> merged_df.to_csv("Resources/merged_data.csv", index=False)
#
# File c:\Users\farza\anaconda3\Anaconda\envs\dev\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\farza\anaconda3\Anaconda\envs\dev\lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\farza\anaconda3\Anaconda\envs\dev\lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File c:\Users\farza\anaconda3\Anaconda\envs\dev\lib\site-packages\pandas\io\common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File c:\Users\farza\anaconda3\Anaconda\envs\dev\lib\site-packages\pandas\io\common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Resources'
